# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("boston.csv")

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
data.corr()["MEDV"]
# Out:
# CRIM      -0.388305
# ZN         0.360445
# INDUS     -0.483725
# CHAS       0.175260
# NOX       -0.427321
# RM         0.695360
# AGE       -0.376955
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.737663
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = data.drop(["MEDV"], axis=1)
y = data["MEDV"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 379  17.86670   0.0  18.10     0  0.671  6.223  100.0  1.3861   24  666.0
# 105   0.13262   0.0   8.56     0  0.520  5.851   96.7  2.1069    5  384.0
# 437  15.17720   0.0  18.10     0  0.740  6.152  100.0  1.9142   24  666.0
# 211   0.37578   0.0  10.59     1  0.489  5.404   88.6  3.6650    4  277.0
# 289   0.04297  52.5   5.32     0  0.405  6.565   22.9  7.3172    6  293.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 474   8.05579   0.0  18.10     0  0.584  5.427   95.4  2.4298   24  666.0
# 99    0.06860   0.0   2.89     0  0.445  7.416   62.5  3.4952    2  276.0
# 270   0.29916  20.0   6.96     0  0.464  5.856   42.1  4.4290    3  223.0
# 227   0.41238   0.0   6.20     0  0.504  7.163   79.9  3.2157    8  307.0
# 492   0.11132   0.0  27.74     0  0.609  5.983   83.5  2.1099    4  711.0
#
#      PTRATIO       B  LSTAT  MEDV
# 379     20.2  393.74  21.78  10.2
# 105     20.9  394.05  16.47  19.5
# 437     20.2    9.32  26.45   8.7
# 211     18.6  395.24  23.98  19.3
# 289     16.6  371.72   9.51  24.8
# ..       ...     ...    ...   ...
# 474     20.2  352.58  18.14  13.8
# 99      18.0  396.90   6.19  33.2
# 270     18.6  388.65  13.00  21.1
# 227     17.4  372.08   6.36  31.6
# 492     20.1  396.90  13.35  20.1
#
# [404 rows x 14 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'ZN'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'CHAS'}>],
#        [<AxesSubplot:title={'center':'NOX'}>,
#         <AxesSubplot:title={'center':'RM'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIS'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'PTRATIO'}>,
#         <AxesSubplot:title={'center':'B'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDV'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
from sklearn.linear_model import LinearRegression

X_train, y_train = train_data.drop(["MEDV"], axis=1), train_data["MEDV"]

reg = LinearRegression()

reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)
X_test, y_test = test_data.drop(["MEDV"], axis=1), test_data["MEDV"]
test_data
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 295   0.12932   0.0  13.92     0  0.437  6.678   31.1  5.9604    4  289.0
# 443   9.96654   0.0  18.10     0  0.740  6.485  100.0  1.9784   24  666.0
# 91    0.03932   0.0   3.41     0  0.489  6.405   73.9  3.0921    2  270.0
# 386  24.39380   0.0  18.10     0  0.700  4.652  100.0  1.4672   24  666.0
# 207   0.25199   0.0  10.59     0  0.489  5.783   72.7  4.3549    4  277.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 335   0.03961   0.0   5.19     0  0.515  6.037   34.5  5.9853    5  224.0
# 37    0.08014   0.0   5.96     0  0.499  5.850   41.5  3.9342    5  279.0
# 294   0.08199   0.0  13.92     0  0.437  6.009   42.3  5.5027    4  289.0
# 130   0.34006   0.0  21.89     0  0.624  6.458   98.9  2.1185    4  437.0
#
#      PTRATIO       B  LSTAT  MEDV
# 295     16.0  396.90   6.27  28.6
# 443     20.2  386.73  18.85  15.4
# 91      17.8  393.55   8.20  22.0
# 386     20.2  396.90  28.28  10.5
# 207     18.6  389.43  18.06  22.5
# ..       ...     ...    ...   ...
# 9       15.2  386.71  17.10  18.9
# 335     20.2  396.90   8.01  21.1
# 37      19.2  396.90   8.77  21.0
# 294     16.0  396.90  10.40  21.7
# 130     21.2  395.04  12.60  19.2
#
# [102 rows x 14 columns]

# %%
reg.score(X_test, y_test)
# Out:
# 0.6359854861793086

# %%
preds = reg.predict(X_test)

# %%
preds
# Out:
# array([28.57878371, 17.89295939, 27.31545322,  5.97359964, 18.27498932,
#        17.72215198, 30.68633724, 34.42956527, 19.89992956, 35.4201153 ,
#        14.43500151, 24.81275649, 17.37191528, 17.95326776, 18.93342779,
#         6.22288469, 27.81160628, 25.1320249 , 24.30450109, 23.27770529,
#        19.09666187, 22.90691659, 24.150935  , 25.92133345, 21.14594751,
#        30.7471724 , 20.08492725, 10.07583934, 31.79773611, 28.43864871,
#        16.14404258, 30.43441005, 34.70583386, 20.70587924, 24.74040545,
#        13.92467278, 14.45187101, 33.24742624, 32.08823501, 34.67468365,
#        20.00503906, 23.34315679, 24.45613845, 30.89199522, 13.23445339,
#        21.91552519, 20.24522706, 17.94313661, 24.75040735, 25.03516969,
#        12.71174241,  6.83000581, 17.32013336, 20.79218249, 19.94494536,
#        12.38622442, 25.80297999, 25.03588964, 21.35984306, 13.61327961,
#        21.5349476 , 22.41030232, 24.82228667, 23.2340203 , 19.8987814 ,
#        17.26100802, 19.39525124, 19.49243112, 22.4134961 , 23.61082672,
#        15.07988769, 31.61717288, 20.35429096, 25.89542788, 25.26256538,
#        15.40851087, 20.22222154, 11.60936814, 16.26532351, 19.59995191,
#        24.73388873, 26.09693576, 31.44549469, 31.82636526, 20.90538361,
#        20.22125896, 24.25216554, 22.70261893, 15.80463293, 24.55211   ,
#        19.12098779, 31.07717797, 26.47749682, 23.01216424, 40.74550283,
#        16.97919578, 17.65466746, 19.82539191, 20.41445215, 22.70564017,
#        24.6691871 , 20.24067644])

# %%
y_test = np.array((y_test))

# %%
preds = np.round(preds, 1)

# %%
for i in range(len(preds)):
    print(preds[i], y_test[i])
# Out:
# 28.6 28.6
# 17.9 15.4
# 27.3 22.0
# 6.0 10.5
# 18.3 22.5
# 17.7 19.4
# 30.7 34.7
# 34.4 34.9
# 19.9 19.4
# 35.4 33.2
# 14.4 19.0
# 24.8 24.2
# 17.4 14.1
# 18.0 16.1
# 18.9 14.1
# 6.2 13.8
# 27.8 22.0
# 25.1 22.9
# 24.3 25.0
# 23.3 20.0
# 19.1 19.9
# 22.9 21.4
# 24.2 24.6
# 25.9 24.8
# 21.1 18.8
# 30.7 37.0
# 20.1 15.0
# 10.1 8.3
# 31.8 27.9
# 28.4 28.4
# 16.1 8.5
# 30.4 31.5
# 34.7 46.7
# 20.7 21.5
# 24.7 23.8
# 13.9 14.0
# 14.5 11.7
# 33.2 32.0
# 32.1 31.1
# 34.7 43.8
# 20.0 24.5
# 23.3 22.4
# 24.5 24.3
# 30.9 32.9
# 13.2 9.5
# 21.9 23.3
# 20.2 23.0
# 17.9 19.6
# 24.8 21.4
# 25.0 21.5
# 12.7 12.7
# 6.8 10.4
# 17.3 19.5
# 20.8 19.3
# 19.9 18.6
# 12.4 13.8
# 25.8 23.1
# 25.0 50.0
# 21.4 18.7
# 13.6 13.1
# 21.5 21.7
# 22.4 24.7
# 24.8 25.0
# 23.2 21.2
# 19.9 17.7
# 17.3 19.9
# 19.4 16.8
# 19.5 18.2
# 22.4 22.4
# 23.6 19.2
# 15.1 21.9
# 31.6 29.1
# 20.4 19.3
# 25.9 19.4
# 25.3 23.2
# 15.4 15.7
# 20.2 17.1
# 11.6 12.0
# 16.3 23.1
# 19.6 19.6
# 24.7 23.1
# 26.1 22.0
# 31.4 24.8
# 31.8 27.5
# 20.9 18.8
# 20.2 20.3
# 24.3 23.1
# 22.7 20.4
# 15.8 14.1
# 24.6 50.0
# 19.1 12.5
# 31.1 32.5
# 26.5 22.8
# 23.0 19.6
# 40.7 50.0
# 17.0 14.9
# 17.7 7.2
# 19.8 18.9
# 20.4 21.1
# 22.7 21.0
# 24.7 21.7
# 20.2 19.2

# %%
test_data
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 295   0.12932   0.0  13.92     0  0.437  6.678   31.1  5.9604    4  289.0
# 443   9.96654   0.0  18.10     0  0.740  6.485  100.0  1.9784   24  666.0
# 91    0.03932   0.0   3.41     0  0.489  6.405   73.9  3.0921    2  270.0
# 386  24.39380   0.0  18.10     0  0.700  4.652  100.0  1.4672   24  666.0
# 207   0.25199   0.0  10.59     0  0.489  5.783   72.7  4.3549    4  277.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 335   0.03961   0.0   5.19     0  0.515  6.037   34.5  5.9853    5  224.0
# 37    0.08014   0.0   5.96     0  0.499  5.850   41.5  3.9342    5  279.0
# 294   0.08199   0.0  13.92     0  0.437  6.009   42.3  5.5027    4  289.0
# 130   0.34006   0.0  21.89     0  0.624  6.458   98.9  2.1185    4  437.0
#
#      PTRATIO       B  LSTAT  MEDV
# 295     16.0  396.90   6.27  28.6
# 443     20.2  386.73  18.85  15.4
# 91      17.8  393.55   8.20  22.0
# 386     20.2  396.90  28.28  10.5
# 207     18.6  389.43  18.06  22.5
# ..       ...     ...    ...   ...
# 9       15.2  386.71  17.10  18.9
# 335     20.2  396.90   8.01  21.1
# 37      19.2  396.90   8.77  21.0
# 294     16.0  396.90  10.40  21.7
# 130     21.2  395.04  12.60  19.2
#
# [102 rows x 14 columns]

# %%
test_data["PRED"] = preds

# %%
test_data
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 295   0.12932   0.0  13.92     0  0.437  6.678   31.1  5.9604    4  289.0
# 443   9.96654   0.0  18.10     0  0.740  6.485  100.0  1.9784   24  666.0
# 91    0.03932   0.0   3.41     0  0.489  6.405   73.9  3.0921    2  270.0
# 386  24.39380   0.0  18.10     0  0.700  4.652  100.0  1.4672   24  666.0
# 207   0.25199   0.0  10.59     0  0.489  5.783   72.7  4.3549    4  277.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 335   0.03961   0.0   5.19     0  0.515  6.037   34.5  5.9853    5  224.0
# 37    0.08014   0.0   5.96     0  0.499  5.850   41.5  3.9342    5  279.0
# 294   0.08199   0.0  13.92     0  0.437  6.009   42.3  5.5027    4  289.0
# 130   0.34006   0.0  21.89     0  0.624  6.458   98.9  2.1185    4  437.0
#
#      PTRATIO       B  LSTAT  MEDV  PRED
# 295     16.0  396.90   6.27  28.6  28.6
# 443     20.2  386.73  18.85  15.4  17.9
# 91      17.8  393.55   8.20  22.0  27.3
# 386     20.2  396.90  28.28  10.5   6.0
# 207     18.6  389.43  18.06  22.5  18.3
# ..       ...     ...    ...   ...   ...
# 9       15.2  386.71  17.10  18.9  19.8
# 335     20.2  396.90   8.01  21.1  20.4
# 37      19.2  396.90   8.77  21.0  22.7
# 294     16.0  396.90  10.40  21.7  24.7
# 130     21.2  395.04  12.60  19.2  20.2
#
# [102 rows x 15 columns]

# %%
test_data = test_data[["MEDV", "PRED"]]

# %%
test_data
# Out:
#      MEDV  PRED
# 295  28.6  28.6
# 443  15.4  17.9
# 91   22.0  27.3
# 386  10.5   6.0
# 207  22.5  18.3
# ..    ...   ...
# 9    18.9  19.8
# 335  21.1  20.4
# 37   21.0  22.7
# 294  21.7  24.7
# 130  19.2  20.2
#
# [102 rows x 2 columns]
